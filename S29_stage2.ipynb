# %% [markdown]
# # Fine tune Projector Layer + Phi2

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from transformers import AutoTokenizer, AutoConfig

# %% [markdown]
# #### MLP projector layer taken from:
# Courtesy: https://github.com/sshh12/multi_token/blob/81ee75cd4435ebd5c7c7c3cf42c136c4053320fb/multi_token/modalities/projectors.py

# %%
def build_patch_mlp_projector(
    input_hidden_size: int, lm_hidden_size: int, num_layers: int
) -> nn.Module:
    modules = [nn.Linear(input_hidden_size, lm_hidden_size, bias=False)]
    for _ in range(1, num_layers):
        modules.append(nn.GELU())
        modules.append(nn.Linear(lm_hidden_size, lm_hidden_size, bias=False))
    return nn.Sequential(*modules)


class _MLPVectorProjector(nn.Module):
    def __init__(
        self, input_hidden_size: int, lm_hidden_size: int, num_layers: int, width: int
    ):
        super(_MLPVectorProjector, self).__init__()
        self.mlps = nn.ModuleList()
        for _ in range(width):
            mlp = [nn.Linear(input_hidden_size, lm_hidden_size, bias=False)]
            for _ in range(1, num_layers):
                mlp.append(nn.GELU())
                mlp.append(nn.Linear(lm_hidden_size, lm_hidden_size, bias=False))
            self.mlps.append(nn.Sequential(*mlp))

    def forward(self, x):
        return torch.cat([mlp(x) for mlp in self.mlps], dim=-2)


def build_mlp_vector_projector(
    input_hidden_size: int, lm_hidden_size: int, num_layers: int, num_tokens: int
):
    return _MLPVectorProjector(
        input_hidden_size, lm_hidden_size, num_layers, num_tokens
    )

# %% [markdown]
# #### Load the projection model that we obtained from Step 1

# %% [markdown]
# #### Use the projector layer + phi2 model from step 1. Use Q&A instead of captions to fine tune the custom model

# %%
from transformers import AutoModelForCausalLM
model_name = "microsoft/phi-2"
phi2 = AutoModelForCausalLM.from_pretrained(
            model_name,
            trust_remote_code=True,
            # torch_dtype = torch.float16
        ).to("cuda")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
class ImageWithPhiLayer(nn.Module):
    def __init__(self,
                 clip_emb:int = 512,
                 token_emb: int = 2560,
                 projection_n_tokens: int = 4,
                 projection_n_layers: int = 1
                ):
        super().__init__()
        self.projection_n_tokens = projection_n_tokens
        self.ll1 = build_mlp_vector_projector(
            clip_emb, token_emb, projection_n_layers, self.projection_n_tokens).to("cuda")
        self.ll1.load_state_dict(torch.load('proj_layer.pth'))
        model_name = "microsoft/phi-2"
        self.tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
        self.vocab_size = len(self.tokenizer)
        self.tokenizer.pad_token = self.tokenizer.eos_token

        self.phi2Model = phi2
        self.token_embedding = self.phi2Model.get_submodule('model.embed_tokens')
        #for name, param in self.phi2Model.named_parameters():
                #param.requires_grad = False

    def generate_text_from_embeddings(self, logits):
        # Apply softmax to obtain probabilities
        probabilities = logits.softmax(dim=2)  # Softmax along the last dimension

        # Find the index of the class with the highest probability for each token in each sequence
        predicted_indices = torch.argmax(probabilities, dim=2)

        # Decode each sequence of predicted indices back into text
        predicted_texts = [self.tokenizer.decode(seq) for seq in predicted_indices]
        #print(predicted_texts)
        return predicted_texts


    def forward(self, x, QnAtokens, QTokenLength, Atokens):
        x = self.ll1(x)
        QnAtoken_embeddings = self.token_embedding(QnAtokens)

        inputs = torch.concat((x, QnAtoken_embeddings), axis=-2)
        outputs = self.phi2Model(inputs_embeds=inputs)
        predictions = self.generate_text_from_embeddings(outputs.logits)

        b,t,v = outputs.logits.shape #batch size, token size, vocab size

        # Calculate loss only for answer part, so take logits from answer token
        for i in range(b):
            output_logits_per_batch = outputs.logits[i,:,:].squeeze(0)

            AtokenSliceLength = Atokens[i].shape[0] -  QTokenLength[i].item()

            if (i == 0):
                loss = F.cross_entropy(
                    output_logits_per_batch[self.projection_n_tokens + QTokenLength[i].item():-2, :],
                    QnAtokens[i][QTokenLength[i].item() + 2:],
                    ignore_index=50256,)
            else:
                loss += F.cross_entropy(
                    output_logits_per_batch[self.projection_n_tokens + QTokenLength[i].item():-2, :],
                    QnAtokens[i][QTokenLength[i].item() + 2:],
                    ignore_index=50256,)

        return loss, predictions

# %% [markdown]
# #### Add adaptors (for image and text modes) using PEFT

# %%
model = ImageWithPhiLayer()
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
import peft
from peft import LoraConfig

lora_alpha = 16
lora_dropout = 0.1
lora_r = 64

peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    target_modules=[
        "Wqkv",
        "out_proj",
        "fc1",
        "fc2",
    ]
)

# %%
import copy
module = model.to('cuda')
peft_model = peft.get_peft_model(module, peft_config)
optimizer = torch.optim.AdamW(module.parameters(), lr=1e-5)
criterion = nn.CrossEntropyLoss()
peft_model.print_trainable_parameters()
# Out:
# trainable params: 52,428,800 || all params: 2,837,355,520 || trainable%: 1.8478050998698958

# %% [markdown]
# #### Get datset that will be used to fine tune Phi-2 + projector layer - use llava_instruct_150k

# %%
import json

instruct_dataset = f'./llava_instruct_150k.json'
with open(instruct_dataset, 'r') as f:
    instruct_data = json.load(f)

# %%
instruct_data[0]
# Out:
# {'id': '000000033471',
#  'image': '000000033471.jpg',
#  'conversations': [{'from': 'human',
#    'value': '\nWhat are the colors of the bus in the image?'},
#   {'from': 'gpt', 'value': 'The bus in the image is white and red.'},
#   {'from': 'human',
#    'value': 'What feature can be seen on the back of the bus?'},
#   {'from': 'gpt', 'value': 'The back of the bus features an advertisement.'},
#   {'from': 'human',
#    'value': 'Is the bus driving down the street or pulled off to the side?'},
#   {'from': 'gpt',
#    'value': 'The bus is driving down the street, which is crowded with people and other vehicles.'}]}

# %% [markdown]
# #### Create a custom dataset that consists of image embedding from CLIP with Q&A from 150k dataset

# %%
from torch.utils.data import Dataset, DataLoader

class CustomTextDataset(Dataset):
    def __init__(self, json_data, image_embedding_dict,  tokenizer, maxContext=1024):
        self.image_embedding_dict = image_embedding_dict
        self.tokenizer = tokenizer
        self.json_data = json_data
        self.maxContext = maxContext

        self.entries = []
        for entry in json_data:
            # Get the text corresponding to the image
            image = entry['image']
            image_embedding = self.getEmbeddingForImage(image)
            if image_embedding is None:
                continue

            conversations = entry['conversations']
            for i in range(len(conversations)):
                if conversations[i]['from'] == 'human':
                    if len(conversations[i]['value'] + conversations[i + 1]['value']) > 512:
                        continue
                    question = 'Question: ' + conversations[i]['value'].lstrip('\n')
                    answer = 'Answer: ' + conversations[i + 1]['value']
                    # Assuming the next message is from 'gpt' and contains the answer
                    self.entries.append({
                        'image_name': image,
                        'image_embedding': image_embedding,
                        'Question': question,
                        'Answer': answer,
                        'QnAText': question + answer
                        })
        print('------------- num entries = -----------------')
        print(len(self.entries))

    def getEmbeddingForImage(self, image):
        if image in self.image_embedding_dict:
            image_embedding = self.image_embedding_dict[image]
            return image_embedding
        else:
            return None

    def __len__(self):
        return len(self.entries)

    def __getitem__(self, idx):
        # Get the entry
        entry = self.entries[idx]
        image_name = entry['image_name']
        Q_caption_tokens = tokenizer.encode(entry['Question'], add_special_tokens=True)
        A_caption_tokens = tokenizer.encode(entry['Answer'], add_special_tokens=True)
        QnA_captions_tokens = tokenizer.encode(entry['QnAText'], add_special_tokens=True)
        QTokensLength = len(Q_caption_tokens)

        Q_caption_tokens = Q_caption_tokens + [tokenizer.pad_token_id] * (self.maxContext - len(Q_caption_tokens))
        A_caption_tokens = A_caption_tokens + [tokenizer.pad_token_id] * (self.maxContext - len(A_caption_tokens))
        QnA_captions_tokens = QnA_captions_tokens + [tokenizer.pad_token_id] * (self.maxContext - len(QnA_captions_tokens))

        return {'image_name': entry['image_name'],
                'QText': entry['Question'],
                'AText': entry['Answer'],
                'image_embedding':  entry['image_embedding'],
                'QTokens':torch.tensor(Q_caption_tokens),
                'ATokens':torch.tensor(A_caption_tokens),
                'QnA_tokens':torch.tensor(QnA_captions_tokens),
                'QTokensLength': QTokensLength
               }

# %%
img_emb = torch.load("img_embeddings.pth").unsqueeze(1)
print(img_emb.shape)
# Out:
# torch.Size([118287, 1, 512])

# %%
with open("./image_names.json", 'r') as file:
    image_names = json.load(file)
imgEmbDict = dict(zip(image_names, img_emb))

# %%
model_name = "microsoft/phi-2"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token

custom_dataset = CustomTextDataset(instruct_data, imgEmbDict,  tokenizer)
custom_dataloader = DataLoader(custom_dataset, batch_size=4, shuffle=True)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ------------- num entries = -----------------
# 225484

# %% [markdown]
# #### Train - finetune the projector layer + Phi-2 peft model with QnA dataset

# %%
# Training loop
num_epochs = 200
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5)

for epoch in range(num_epochs):
    model.train()
    for ix, batch in enumerate(custom_dataloader):
        embeddings = batch['image_embedding'].to('cuda')
        QnAtokens = batch['QnA_tokens'].to('cuda')
        QTokenLength = batch['QTokensLength'].to('cuda')
        ATokens = batch['ATokens'].to('cuda')

        loss, predictions = peft_model(embeddings, QnAtokens, QTokenLength, ATokens)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if ix % 10 == 0:
            print("------------captions text = -------------------")
            print(batch['QText'][0])
            print(batch['AText'][0])
            print("------------Teacher forced predictions text = -------------------")
            print(predictions[0].rstrip('<|endoftext|>').rstrip("\n")[:200])
            print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {loss.item()}")
    torch.save(
        peft_model.state_dict(),
        "stage_2_model.pth"
    )
# Out:
# ------------captions text = -------------------
# Question: Describe the color and type of backpack the baseball player is carrying.
#
# Answer: The baseball player is carrying a pink feminine backpack while walking onto the field.
# ------------Teacher forced predictions text = -------------------
# -,. a mark aending the scene of shape of the. girl player is wearing. A| src
# : A baseball player is carrying a red backpack backpack. wearing on the field.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 30.28024673461914
# ------------captions text = -------------------
# Question: Where is the garbage truck in relation to the garbage cans?
# Answer: The garbage truck is near two garbage cans on the side of the road, possibly picking up trash from those cans at the curb.
# ------------Teacher forced predictions text = -------------------
#
# ,. a: a a the cat can going the to the house can? : The garbage truck is in the garbage cans. the street of the road. but in up trash. the cans. this same.
# The
#
#
#
#
#
# The
#
#
#
#
#
#
#
# The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 30.051097869873047
# ------------captions text = -------------------
# Question: Where are the men standing in the room?
# Answer: The men are standing together in the corner of a room, which might indicate that they are in a larger space or participating in an event happening nearby.
# ------------Teacher forced predictions text = -------------------
# _,.
#  of A is you people?? the picture? : A men are standing in in a room of the room. with is be that they are in a meeting room. a in a event. in.  TheTheTheTheTheTheTheTheTheTheTheTheTheTheTheTheThe
# Epoch 1/200, Loss: 30.013338088989258
# ------------captions text = -------------------
# Question: Are there any people visible in the living room?
# Answer: No, there are no people visible in the living room. The room is clean and empty of people.
# ------------Teacher forced predictions text = -------------------
#
# , Club a a A you any people on in the picture room? : Yes, there are no people in in the living room.
#  only is empty and tidy. any. TheThe
#
#
# The
#
# TheThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 28.5336856842041
# ------------captions text = -------------------
# Question: What are the main ingredients on the plate in the image?
# Answer: The main ingredients on the plate in the image are chicken, carrots, and Brussel sprouts.
# ------------Teacher forced predictions text = -------------------
# _,.
#  of a is you ingredients ingredients in this plate? this picture? : The main ingredients on the plate are the image are a, rice, and potatoessel sprouts.
#
#
#
#
#
#
#
#
#
# The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 29.092382431030273
# ------------captions text = -------------------
# Question: What is the color of the surfer's shirt?
# Answer: The surfer is wearing an orange shirt.
# ------------Teacher forced predictions text = -------------------
#
# ,. a a a is a picture of the skyfer? board? : The surfer is wearing a orange shirt.
# TheThe
#
#
#
# The
#
# The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 28.20981216430664
# ------------captions text = -------------------
# Question: What is the person doing on the boat? Are they riding or sitting?
# Answer: The young boy is sitting on the sailboat.
# ------------Teacher forced predictions text = -------------------
# .,. a a a is a view doing in the beach?  they fishing a swimming?
#  The person man is riding on the boatboat. HeTheTheTheTheTheTheTheThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 26.161998748779297
# ------------captions text = -------------------
# Question: How would you describe the living room's source of natural light?
# Answer: The living room is equipped with a large window that allows for ample natural light to enter the space during daytime hours.
# ------------Teacher forced predictions text = -------------------
#
# _. a a a a you describe a picture room?? of light light?  the The room room is a with a window window. lets natural natural natural light. enter the room. the..
# TheTheTheTheTheTheTheTheTheTheTheTheTh
# Epoch 1/200, Loss: 22.439565658569336
# ------------captions text = -------------------
# Question: Is the laptop using a separate keyboard and mouse?
#
# Answer: Yes, the laptop in the image is set up with a separate keyboard and a wireless mouse.
# ------------Teacher forced predictions text = -------------------
#
# ,. a a a a a is a computer screen. mouse. aAa src is the laptop, the laptop is the picture is using up with a keyboard keyboard and mouse mouse mouse.
# TheThe
#
#
# The
#
#
#
# The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 20.6652889251709
# ------------captions text = -------------------
# Question: What is the position of the elephant relative to the car?
# Answer: The elephant is positioned in front of the car and appears to be looking in the window, as it is walking or standing near the vehicle.
# ------------Teacher forced predictions text = -------------------
# -,. a a a a a a of the a and to the other. the the The elephant is in in the of the car. the to be in at the direction. the well is the. standing. the car.
# TheTheTheTheTheTheTheThe
#
# TheTheTheThe
#
#
#
#
#
#
# Epoch 1/200, Loss: 17.967504501342773
# ------------captions text = -------------------
# Question: In what kind of setting is the market or fruit stand located?
# Answer: The market or fruit stand is located in a tropical setting, as indicated by the presence of coconuts and bananas, which are both tropical fruits.
# ------------Teacher forced predictions text = -------------------
#
# ,. a a a a is of a is a a is the stand.. the the The market or fruit stand is located in the setting setting. the well by the palm of palmonuts and palm. and are tropical tropical fruits.
# The
# TheTheT
# Epoch 1/200, Loss: 20.983009338378906
# ------------captions text = -------------------
# Question: Are there any other elephants in the image?
# Answer: Yes, there are other elephants following the one with people on its back.
# ------------Teacher forced predictions text = -------------------
# -,. a a a a a people people in the room. the the a elephants there are elephants elephants in the image in the. the..
# TheThe
#
# The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 21.886499404907227
# ------------captions text = -------------------
# Question: Are there any trees visible in the picture? If so, what is their condition?
# Answer: Yes, there are leafless trees visible in the picture, suggesting that the image may have been taken during the fall or winter season when trees typically lose their leaves.
# ------------Teacher forced predictions text = -------------------
# -,. a a a a a the in the the background. trees the, the are the color? The the The there there trees trees trees trees in in the picture. the the they trees is be been taken in the winter. winter.. tr
# Epoch 1/200, Loss: 19.445453643798828
# ------------captions text = -------------------
# Question: What is the young man wearing?
# Answer: The young man is wearing white clothing.
# ------------Teacher forced predictions text = -------------------
# .,_ a a a a a a man a a man man man man man wearing wearing a shirt. TheTheThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 16.8259334564209
# ------------captions text = -------------------
# Question: What can be inferred about the person's snack preference?
#
# Answer: Based on the image, it can be inferred that the person has a preference for doughnuts as a snack. Their hand is shown holding a half-eaten doughnut wrapped in wax paper, with a bite missing from it. This implies the person enjoys the taste of doughnuts and potentially considers them as a favorable snack choice.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a is be seen from the the is the is. aAa>A the The on the image the the can be inferred that the person is a preference for thenuts. they snack. The preference is holding holding a dough aeate
# Epoch 1/200, Loss: 19.806129455566406
# ------------captions text = -------------------
# Question: Is this image taken during a baseball game or practice?
# Answer: This image is taken during a baseball game, with multiple people participating in the match on the field.
# ------------Teacher forced predictions text = -------------------
# -,. a a a a a a a a a game. a. baseball baseball Yes is is baseball baseball baseball baseball game. baseball players players...... field. TheTheTheThe
# TheTheThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 15.670476913452148
# ------------captions text = -------------------
# Question: Is there a fireplace in the living room?
# Answer: Yes, there is a fireplace in the living room next to the red couch.
# ------------Teacher forced predictions text = -------------------
#  ,. a a a a a a a a room room. The The fireplace fireplace fireplace is a fireplace in the living room. to.... TheThe
#
#
#
# The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 16.070781707763672
# ------------captions text = -------------------
# Question: What color is the traffic light in the image?
#
# Answer: The traffic light in the image is showing a green light.
# ------------Teacher forced predictions text = -------------------
#
# ,. a a a is is the a light is the.. TheThebr> the the The traffic light is the image is red red red.. greenThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 13.516036987304688
# ------------captions text = -------------------
# Question: What is the color of the building near the railroad tracks?
# Answer: The color of the building near the railroad tracks is white.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a a a a of the a a the street.. building The The building of the building is the railroad tracks is blue. TheTheThe
#
# TheThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 14.302488327026367
# ------------captions text = -------------------
# Question: Are there any people in the image?
# Answer: No, there are no people in the image, only the snowboards are present.
# ------------Teacher forced predictions text = -------------------
# ,_. a a a a are a in the a a people The image people there people no people in image image. there...... TheTheTheTheTheTheTheTheThe
#
#
#
# The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 15.062517166137695
# ------------captions text = -------------------
# Question: What can you infer about the relationship between the man and the girl in this image?
# Answer: Although we cannot be certain about the exact relationship between the man and the girl, it is likely that the man is a caretaker, guardian, or instructor. The scenario implies that he is providing guidance and supervision for the girl while she rides the horse, ensuring her safety and teaching her proper horse riding techniques.
# ------------Teacher forced predictions text = -------------------
# -,. a a a a a see from the the between the two and dog dog. the image. man The man the can see sure the the relationship relationship between the man and girl girl in we is can that they man and the t
# Epoch 1/200, Loss: 18.934972763061523
# ------------captions text = -------------------
# Question: What type of track are the trains situated on?
# Answer: The trains are situated on a steel track.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a a of is is train train on on. trains The The trains on on on a, track. TheTheTheTheTheTheThe
#
#
# TheTheThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 16.0361328125
# ------------captions text = -------------------
# Question: What is the woman doing while walking on the street, and how does this affect her posture?
#
# Answer: The woman is talking on her cell phone while walking down the street, holding the phone to her ear using her shoulder. This posture involves her leaning her head toward the shoulder and placing the phone between her ear and shoulder while she walks. This might not be the most comfortable or ergonomic position for an extended period, but it allows her to keep her hands free while she is using the phone.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a is a a holding with sitting. street street. the. she she. her.. woman womana_ woman The woman woman walking walking on phone phone phone while walking on street street, and the phone in her
# Epoch 1/200, Loss: 17.908044815063477
# ------------captions text = -------------------
# Question: Is the photo in color or black and white?
# Answer: The photo is black and white, which gives it an old or vintage appearance.
# ------------Teacher forced predictions text = -------------------
# -,. a a a a a a a or black and white. the The photo is black black and white and and is a a old. vintage feel. blackTheTheTheTheThe
# TheThe
# The
#
# The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 14.511215209960938
# ------------captions text = -------------------
# Question: What type of device is on the bed?
# Answer: There is a laptop on the bed, placed on one side.
# ------------Teacher forced predictions text = -------------------
# _,, a a A a of is is a the the a a The device is a a on the bed. laptop on the side. TheThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 13.568617820739746
# ------------captions text = -------------------
# Question: What is the girl wearing?
# Answer: The girl is wearing a pink dress.
# ------------Teacher forced predictions text = -------------------
# -,, a a a a a a a a girl The girl girl wearing wearing a... TheTheThe
#
#
# The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 14.621248245239258
# ------------captions text = -------------------
# Question: What is the woman holding in her mouth?
# Answer: The woman is holding the man's tie in her mouth.
# ------------Teacher forced predictions text = -------------------
# -,. a a a a a a a a hand hand a woman The woman woman holding holding a in in in in her.. TheTheTheTheTheTheTheThe
#
# TheThe
#
#
#
#
# TheThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 13.722742080688477
# ------------captions text = -------------------
# Question: Is the man a professional tennis player or an amateur player?
# Answer: The image does suggest that the man could be a professional tennis player, given his athletic posture and the intensity of his shot. However, it is not possible to definitively confirm his professional status just by looking at the image. He could also be an amateur player with a good skill level.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a a a a on a player or is..? professional The man man is man professional the man is be professional professional tennis player amateur as the attire and and tennis tennis of the.. The, the is
# Epoch 1/200, Loss: 15.364144325256348
# ------------captions text = -------------------
# Question: What type of landscape do the horses appear to be in?
# Answer: The horses appear to be in a grassy field or open land with hills in the background, suggesting a rural or countryside landscape.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a a of is is in a in in be in a The The horses horses in in in in a fieldy field a field.. trees.. background. the a. area country.. TheTheThe
#
# The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 15.255200386047363
# ------------captions text = -------------------
# Question: What kind of toilet is the child using?
# Answer: The child is using a child's potty or a small kids' toilet, which is specifically designed for young children and toddlers who are learning how to use the bathroom independently. These potty seats are often smaller and lower to the ground to accommodate the size and physical abilities of young children.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a a of is is in in in a child The child child using using a a a toiletty. toilet toilet toilet toilet toilet. a is small designed for. children. small. are not to to use the... the arety are a
# Epoch 1/200, Loss: 16.082761764526367
# ------------captions text = -------------------
# Question: What position does the baseball player hold on the field?
# Answer: The baseball player is playing the position of a pitcher on the field.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a is a man a in is the field field. player The player baseball player is on in field catcher catcher catcher.. field. theThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 12.864726066589355
# ------------captions text = -------------------
# Question: How many people are in the group of skateboarders at the skate park?
#
# Answer: There are four young skateboarders at the skate park.
# ------------Teacher forced predictions text = -------------------
# -,. a a a to the a in the room a people....... ThereThereans. The There There a a people peopleboard at at the park park. the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 16.408159255981445
# ------------captions text = -------------------
# Question: What is the facial expression of the young girl in the image?
# Answer: The young girl appears happy and joyful in the image, as she holds the huge stuffed bear.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a is the a a a man man girl.... girl The girl girl girl in to and smiling. image image. smiling she smiling a a... The
# TheTheTheTheTheThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 16.37301254272461
# ------------captions text = -------------------
# Question: What is the setting of the image? Is it a desert or an area with trees?
# Answer: The setting of the image is an area with trees and thicket, not a desert.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a a a a a a a a image a a a or beach.... the The image image is image is is desert desert with trees a desert grass. the desert desert. TheThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 15.258715629577637
# ------------captions text = -------------------
# Question: What does the field look like?
# Answer: The field is lush and green, which is characteristic of a well-maintained baseball field.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a is a a a a a field The field field is grass green green grass with grass grass of grass..maint.... grassTheTheThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 10.976597785949707
# ------------captions text = -------------------
# Question: Is the bicyclist riding on a separate bike path or sharing the street with other vehicles?
# Answer: The bicyclist is riding along a city bike path, indicating a dedicated space for cyclists separate from the main street where other vehicles like the red truck are driving.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a a a a a a the street or.. road the..... the The is bicycl is is on on separate bike bike path. separate separate separate. for.. from other street street. other vehicles. cars cars car... Th
# Epoch 1/200, Loss: 15.76730728149414
# ------------captions text = -------------------
# Question: What object is next to the donuts in the image?
# Answer: A cup of coffee is next to the donuts in the image.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a is is on to the a a the the image a the The next in of coffee next next the don don the in image image. theTheThe
# TheTheTheThe
#
# TheThe
#
#
#
#
# The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 15.889286041259766
# ------------captions text = -------------------
# Question: What is the main focus of the image?
#
# Answer: The main focus of the image is a woman in a yellow bikini holding a surfboard at the beach.
# ------------Teacher forced predictions text = -------------------
# _,, a a a the the a a the the image. imageThe There a the The main main focus of image is is a a a a. dress a a a.. beach beach. the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 14.356645584106445
# ------------captions text = -------------------
# Question: Are the children sitting or standing while playing the game?
# Answer: The children are standing in a room while playing the Wii game.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a the on playing on standing a playing?.. Yes Yes children children are sitting playing playing playing playing playing game game.. standingThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 12.308329582214355
# ------------captions text = -------------------
# Question: How is the baby elephant positioned in relation to the adult elephant?
# Answer: The baby elephant is standing next to the adult elephant, close to its trunk.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a a the a the the the image to.... the The baby baby is is in next adult adult adult elephant. the the... theTheThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 13.039802551269531
# ------------captions text = -------------------
# Question: What is the landscape like in the image?
# Answer: The landscape in the image is a large, grassy field with tall grass, providing a natural environment for the giraffes. The sky is also visible in the background, which adds to the feeling of openness and vastness in the scene.
# ------------Teacher forced predictions text = -------------------
# ,,, a a a is the a a a.. a landscape The landscape landscape the image is is a a a withy, with trees trees and trees a. setting......, the the blue the the the image, the is to the natural of natural.
# Epoch 1/200, Loss: 16.85420036315918
# ------------captions text = -------------------
# Question: Where are the suitcases and luggage bags displayed?
# Answer: The suitcases and luggage bags are displayed on a sidewalk, lined up for potential buyers to check them out.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a a the the the the bags the the the bags The suit arecases and luggage bags are displayed on the shelf. the the side....... bagsTheThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 15.150497436523438
# ------------captions text = -------------------
# Question: What color is the fire hydrant in the image?
#
# Answer: The fire hydrant in the image is purple.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a the is the of therant the image image? theThe The_ The The is is hydrant is image image is red. the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 10.297492980957031
# ------------captions text = -------------------
# Question: What color is the plate that holds the scallops?
# Answer: The plate holding the scallops is white.
# ------------Teacher forced predictions text = -------------------
# ,,, a a a is is the the the on food food and the the the The plate plate the sc sc isops is white. plate
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 13.681195259094238
# ------------captions text = -------------------
# Question: What type of bed is shown in the image?
# Answer: The image shows a bed with pillows and stuffed animals on it. It is a residential bedroom scene, featuring a black frame and floral sheets. The bed may be a waterbed, but it is not possible to determine this with certainty from the image alone.
# ------------Teacher forced predictions text = -------------------
# .,. a A a a of is is in the image. a image The image is shows a bed a a and and blanket.... the a a a a.. with a bed bed a white.. The bed is be queen queen or or as not is not. to tell from from imag
# Epoch 1/200, Loss: 15.691458702087402
# ------------captions text = -------------------
# Question: Is there a plant on the back of the toilet tank?
# Answer: Yes, there is a plant on the back of the toilet tank.
# ------------Teacher forced predictions text = -------------------
# ,,, a a a a a in in the of of.... yes Yes, there there plant plant plant on the back of toilet. tank. theThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 11.662046432495117
# ------------captions text = -------------------
# Question: Are the boats moving or stationary?
# Answer: Some boats, like the canoe with the canoeist, are in motion, whereas other boats, such as the empty rowboat, seem to be stationary.
# ------------Teacher forced predictions text = -------------------
# ,,, a a a the the the the stationary the boats Yes boats boats moving the,,,,,,, are moving water the the other,,, as,,,,, stationary. stationary.. theThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 14.76218032836914
# ------------captions text = -------------------
# Question: Are there any people visible in the image, and if so, where are they in relation to the dog?
# Answer: Yes, there are people visible in the image. Their feet are shown next to the small dog that is laying on the ground, trying to get closer and sniff them.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a the people the in the image.? the if so, what? they the image the the.., Yes, there there people people in the image image they the are the the the the dog dog dog the the in on the.. the to
# Epoch 1/200, Loss: 13.422354698181152
# ------------captions text = -------------------
# Question: What additional structure or object is visible near the clock tower?
# Answer: There is a statue near the clock tower, as well as a sculpture on display.
# ------------Teacher forced predictions text = -------------------
# ,,, a a a a a the is the the the the. a? the The near a a a near the clock tower. the a a a.. the the the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 13.757111549377441
# ------------captions text = -------------------
# Question: Is there anything unusual about the dishwasher?
# Answer: Yes, the dishwasher is overfilled, which might indicate that there are too many dishes to fit in it properly, requiring some dishes to be placed on the floor in a tray.
# ------------Teacher forced predictions text = -------------------
# _,. a a a a a the the the the the the There There, there there iswasher unusual unusual the the with is be that not more dishes dishes dishes in fit in... and more to to be washed in top..... the
#
#
#
#
#
# Epoch 1/200, Loss: 13.50675106048584
# ------------captions text = -------------------
# Question: What color is the street sign in the image?
#
# Answer: The street sign in the image is white.
# ------------Teacher forced predictions text = -------------------
# -,. a a a a the the a a the image. a streetThe The> The The sign in in the image is is red. the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 9.768667221069336
# ------------captions text = -------------------
# Question: Are there any other visible objects or people in the image?
# Answer: There are no other visible objects or people other than the person sleeping in bed, the cell phone, the white bed sheets, and the nearby light fixture.
# ------------Teacher forced predictions text = -------------------
# -,, a The a the people the the the the in the the. a image There, are other other visible in people people the the the. the the.. and and phone and and and and and and and the.... theThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 12.51406478881836
# ------------captions text = -------------------
# Question: What is the position of the man the police officers are interacting with?
# Answer: The man is sitting on the side of the street near a street sign.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a the the a the the the the the????? the The man man the on on bench ground of the police the police. a a theThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 14.265809059143066
# ------------captions text = -------------------
# Question: What is the main dish on the plate of food?
# Answer: The main dish on the plate of food is a sandwich.
# ------------Teacher forced predictions text = -------------------
# ,,_ a a a a a a of the the plate a? a main The main main on the plate is food is is salad, with sandwich
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 13.396778106689453
# ------------captions text = -------------------
# Question: What type of view does the photograph capture?
# Answer: The photograph captures a fish-eye view of the men's bathroom, which provides a wide-angle perspective of the interior space, including the urinals and sinks.
# ------------Teacher forced predictions text = -------------------
# -,, a A A the of is the the have have a photograph The photograph is a a view a a view the a. a.. the is a. viewangle view..... the sinks sink and and sinks.,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 13.319397926330566
# ------------captions text = -------------------
# Question: How is the breakfast food arranged on the plate?
# Answer: The breakfast food is arranged with the omelet and hash browns placed on the plate, and the toast is either beside the plate or alongside the other items on the plate.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a a the the a served the plate plate. breakfast The breakfast on on arranged arranged the on onme on the eggs ons on on plate plate with with fruit fruit on on side or or or on the...... The
#
#
# Epoch 1/200, Loss: 12.990100860595703
# ------------captions text = -------------------
# Question: Is this a close-up photo?
# Answer: Yes, this is a close-up photo showing the bananas, apple, and oranges.
# ------------Teacher forced predictions text = -------------------
# -,, a The a the a a aup of a Yes Yes photo, photo a a close upup photo a a of.. and and.. theThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 13.186002731323242
# ------------captions text = -------------------
# Question: What is the surface the pizzas are placed on?
# Answer: The pizzas are placed on a black countertop or a large cutting board.
# ------------Teacher forced predictions text = -------------------
# -,. a a a a the the the a a on on on the the The pizz are are placed placed on a......... TheThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 13.794365882873535
# ------------captions text = -------------------
# Question: Is the skateboarder a child or a young adult?
# Answer: The skateboarder is a young adult.
# ------------Teacher forced predictions text = -------------------
# -,, a A a the aboarder the a or adult adult adult The skate The skate isboarder a a young adult The,The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 9.177595138549805
# ------------captions text = -------------------
# Question: What sport is being played in the image?
# Answer: In the image, the sport being played is baseball.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a the the the played the image image a sport The sport image image a playing playing played played is tennis. playersThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 13.981587409973145
# ------------captions text = -------------------
# Question: Is the bookstore's window display appealing to a specific age group or a wider audience?
# Answer: The bookstore's window display looks appealing to both children and adults, attracting a wider audience.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a a a a a display attractive????? or???? the The display window window window display appealing appealing a a a and adults. as a a audience. display
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 10.878798484802246
# ------------captions text = -------------------
# Question: What is the color of the flowers in the vase?
# Answer: The flowers in the vase are red.
# ------------Teacher forced predictions text = -------------------
# -,. a A A the the the the the a the v.ase the flowers The flowers in the v are are are white.,The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 10.158352851867676
# ------------captions text = -------------------
# Question: What is the main activity that the skiers are engaged in?
# Answer: The skiers are mainly engaged in hiking up the side of a snow-covered mountain.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a the the the of the the in is the doing in the The The main areiers the engaged engaged in, the and mountain a mountain..covered mountain the,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 12.552297592163086
# ------------captions text = -------------------
# Question: What object is being threatened to be cut in the image?
# Answer: A British pound note, specifically a UK 10 pound note, is being threatened to be cut in the image.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a the the the a a the by the image? a object In man in in the the the a in,, in in the being in cut cut cut the image.. note
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 13.193543434143066
# ------------captions text = -------------------
# Question: How many donuts are displayed in the image?
#
# Answer: There are two donuts displayed in the image.
# ------------Teacher forced predictions text = -------------------
# ,,. a A a the people a the the the image image a ThereTherea2 There There are two don donuts the the image.. the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 9.515918731689453
# ------------captions text = -------------------
# Question: Where is the man holding the stop sign located?
#
# Answer: The man holding the stop sign is located on the side of a road, in a rural or wooded area.
# ------------Teacher forced predictions text = -------------------
# ,,, a a a a located located a surf.. the the manThe a> man The man is holding stop is is the the the street. the... the front.. areaed area. the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 13.411294937133789
# ------------captions text = -------------------
# Question: Is the bathroom window above the toilet or sink?
# Answer: The bathroom window is located above the toilet, with a white toilet sitting under it.
# ------------Teacher forced predictions text = -------------------
# ,,_ a a a a a a open or or or the? bathroom The bathroom above window above above above toilet toilet the providing a of. the the window. the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 10.559746742248535
# ------------captions text = -------------------
# Question: Are there other people present in the image?
# Answer: Yes, there are people walking down the sidewalk as well.
# ------------Teacher forced predictions text = -------------------
# ,,. a a A the people in the the the. a If There, there there a people in the street street the the the the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 10.39732551574707
# ------------captions text = -------------------
# Question: What is the background environment of the tennis court?
# Answer: The background environment of the tennis court includes fencing.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a the the a the the girl..? background The background of the tennis tennis tennis is is tennis and the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 14.401481628417969
# ------------captions text = -------------------
# Question: What are some aspects of the living room's design that stand out?
# Answer: Some standout aspects of the living room's design include the nice decorating job and the presence of a ceiling fan. This gives the impression of a well-decorated and comfortable space where people can relax and enjoy leisure time.
# ------------Teacher forced predictions text = -------------------
# ,,, a The a the the of of the of room the design?, out the The The aspects aspects features the room room room design design include,,,,, the,, of, fireplace.., fan room room the a and decorateddesign
# Epoch 1/200, Loss: 13.0850830078125
# ------------captions text = -------------------
# Question: Is there a magnifying glass involved in the image or just the rear view mirror?
# Answer: The image features a rear view mirror reflecting the building; there is no magnifying glass involved.
# ------------Teacher forced predictions text = -------------------
# ,,_ a A A the a in in in the the image?? not a... the magn There magn is a a magn mirror mirror magn a. a magn a magn magn in the the the The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 16.23448944091797
# ------------captions text = -------------------
# Question: Where is the scene taking place?
# Answer: The scene is taking place at an intersection in a city.
# ------------Teacher forced predictions text = -------------------
# ,,_ a a a a the a taking place? scene The scene is taking taking place a beach.. city.. the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 9.383478164672852
# ------------captions text = -------------------
# Question: What is the main animal visible in the image?
#
# Answer: The main animal visible in the image is a giraffe.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a a the the of the the image. a main
# ans_ The The main main in visible the image is a elephant... gir
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 10.331340789794922
# ------------captions text = -------------------
# Question: What types of food can be seen on the plates in this image?
# Answer: In this image, we can see various plates of food, including french toast, chips (also known as fries), and likely some fried breakfast items. There are also beverages and silverware present, indicating a complete meal is laid out on the table.
# ------------Teacher forced predictions text = -------------------
# ,,, a a a the of animals the be found the the table the the?? The There the image, there food can see a types food food the including,,,,,, known as chips), and. a... such the a also a the aware the t
# Epoch 1/200, Loss: 15.370288848876953
# ------------captions text = -------------------
# Question: What is the primary color of the dog in the image?
#
# Answer: The primary color of the dog in the image is white.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a the the the of the the of the image?? TheThe The> The The color color color the dog in the image is is.. dog
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 9.920082092285156
# ------------captions text = -------------------
# Question: Why might a giraffe stretch its neck and head over a fence like this?
# Answer: A giraffe might stretch its neck and head over a fence for several reasons, such as trying to reach food, interacting with people or other animals, or simply being curious about its surroundings. Giraffes have long necks which provide them with a height advantage, enabling them to easily reach over barriers like fences and allowing them to explore or observe their environment with ease.
# ------------Teacher forced predictions text = -------------------
# ,,, a There a the a be be be its neck up head up fence fence??? gir A gir gir may may stretch its neck and head over fence fence to to reasons. it to to to reach food or or with other or other animals
# Epoch 1/200, Loss: 11.935430526733398
# ------------captions text = -------------------
# Question: What other objects are present in the bathroom besides the toilet?
# Answer: Besides the toilet, there are a sink and a shower in the bathroom.
# ------------Teacher forced predictions text = -------------------
# ,,, a a a the the in in the the room the toilet and? other There other toilet,, are a sink and and mirror mirror in bathroom.. the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 9.92363166809082
# ------------captions text = -------------------
# Question: Is the cake mixture fully mixed or are the individual ingredients still visible?
# Answer: Based on the image, it seems that the cake mixture has been blended together, but it's still possible to identify the individual ingredients, such as peanut butter and chocolate, to some extent.
# ------------Teacher forced predictions text = -------------------
# ,,_ a a a the a a ready or the not there ingredients ingredients??? Yes The mixture on image image the cake appears the cake are mixture not not and but but the there not not visible some see individu
# Epoch 1/200, Loss: 13.955324172973633
# ------------captions text = -------------------
# Question: Is the dog drinking water from the bowl or eating food?
# Answer: The dog is eating food from the dog bowl, not drinking water.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a the a the water a bowl. the the?? The The dog is drinking eating food the bowl bowl bowl the not water water the The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 10.76658821105957
# ------------captions text = -------------------
# Question: In which direction does the sign point for the police station?
# Answer: The sign pointing to the police station is directed to the left.
# ------------Teacher forced predictions text = -------------------
# ,,. a A a image, the the cat the????? sign The sign sign points the police police is is facing the the. the the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 8.59724235534668
# ------------captions text = -------------------
# Question: What is the setting of the image?
# Answer: The image is set in a grassy area or field, possibly a park.
# ------------Teacher forced predictions text = -------------------
# ,,, a a a the the the the the?? image The setting of a a a a,y field a field a the a park or the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 13.727819442749023
# ------------captions text = -------------------
# Question: Has the batter successfully hit the baseball?
# Answer: Yes, the batter has successfully hit the baseball and is preparing to run the bases.
# ------------Teacher forced predictions text = -------------------
# _,, a a a a a a the the ball the The Yes, the batter is successfully successfully hit baseball baseball the is running to....,The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 9.773456573486328
# ------------captions text = -------------------
# Question: What color is the traffic light displayed in the image?
# Answer: The traffic light in the image is displaying red.
# ------------Teacher forced predictions text = -------------------
# ,,_ a a a the the the of light? the image?? the The light in in displayed image is is... is
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 13.501922607421875
# ------------captions text = -------------------
# Question: What color is the cat?
# Answer: The cat is yellow and white.
# ------------Teacher forced predictions text = -------------------
# ,,. a A a the the the of the cat The cat is white.... The
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 10.873489379882812
# ------------captions text = -------------------
# Question: What are the children wearing?
# Answer: The children are wearing uniforms, which might indicate that they are in a school setting or part of a sports team.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a the the the doing the the The children are wearing wearing.. they are be they they are part school or or a activity a a group team. uniforms
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 11.147897720336914
# ------------captions text = -------------------
# Question: What is the main subject of the image?
#
# Answer: The main subject of the image is a street pole with a street name sign, specifically a sign that says "Jack Kerouac."
# ------------Teacher forced predictions text = -------------------
# -,_ a a a the the the of the image. a mainTheans> The The main main of the image is a a a a a a sign. a. and the, the the "street street.." is
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 14.32810115814209
# ------------captions text = -------------------
# Question: What type of food is displayed in the image?
#
# Answer: The image displays a variety of food, including a vegetable platter with carrots and cauliflower, a fruit platter with kiwi and some chicken bites, and a bowl containing nuts like walnuts.
# ------------Teacher forced predictions text = -------------------
# ,,. a a a the of is is the the the on a TheTheans> The The image is a a of of food including including,,,,,,,,,,, of bowl with with applesiw,,,,, a a a bowl of of and almonds and and are
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 15.30413818359375
# ------------captions text = -------------------
# Question: Where is the woman laying in the image?
#
# Answer: The woman is laying on a surfboard on the floor in a room.
# ------------Teacher forced predictions text = -------------------
# ,,. a A a the the is the the image?? theTheans> The The woman is laying on the bed bed the the beach. a image room a is
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 8.701106071472168
# ------------captions text = -------------------
# Question: Is the man sitting outside or inside?
# Answer: The man is sitting inside, as evidenced by the open doorway to a room with lit computer monitors in the background.
# ------------Teacher forced predictions text = -------------------
# ,,_ a The a the is the the the inside a The The man is sitting outside outside a a he a the and window the building room the....... is
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 11.301718711853027
# ------------captions text = -------------------
# Question: What are the people doing in the field?
# Answer: The people in the field are playing with a Frisbee, with one person throwing it and others either attempting to catch or throw it back.
# ------------Teacher forced predictions text = -------------------
# .,. a A The the the the the the the.? people The people are the field are are playing soccer a..bee the a the on throwing the the another catching catching catch catch or. the.. areThe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 11.315132141113281
# ------------captions text = -------------------
# Question: What kind of vehicles are present in the Lego scene?
# Answer: In the Lego scene, there is a police car, an ambulance, and a fire engine, along with other vehicles typically found in a city setting.
# ------------Teacher forced predictions text = -------------------
# ,,_ a The The is of is are in the image? scene? cars The scene Lego scene, there are a large truck, a a, and a fire... are a police vehicles the in a city... vehicles
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 9.94809627532959
# ------------captions text = -------------------
# Question: What is the color of the truck in the image?
# Answer: The truck in the image is a brightly colored orange and black Ford truck.
# ------------Teacher forced predictions text = -------------------
# ,,, a The The is the of the the on the image?? The The color in the image is red.. color. white... which is
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 9.599912643432617
# ------------captions text = -------------------
# Question: What is the demeanor of the bears? Are they agitated, calm, or playful?
# Answer: The two bears seem to be calm and relaxed while sitting together in their environment.
# ------------Teacher forced predictions text = -------------------
# ,,, a The The is the of the woman in the the bears or or or or or?? The The bears are are the be agitated and playful, as on the the enclosure. They are
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 8.2144775390625
# ------------captions text = -------------------
# Question: What is the main activity of the flamingos in the water?
# Answer: The main activity of the flamingos in the water is standing and possibly finding food.
# ------------Teacher forced predictions text = -------------------
# ,,, a The The is the of of the people in in the image?? The The main activity of the flamingos in the water is walking for walking on in to the flaming
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 12.292854309082031
# ------------captions text = -------------------
# Question: What items are placed on the table?
# Answer: There are condiments and a blue mug of coffee placed on the table.
# ------------Teacher forced predictions text = -------------------
# ,,, a The The is are in on table table the a The table a,, such on on on on on on the table. the is
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 9.633523941040039
# ------------captions text = -------------------
# Question: How are the flowers displayed in front of the window?
# Answer: The flowers are displayed in front of the window in a tall, thin clear glass vase or a tall glass pole, which is placed on a glass stand.
# ------------Teacher forced predictions text = -------------------
# ,,, the The The the the in in the v the house?? The The flowers are displayed in a of the window, a v arrangement v arrangement,... whichaseasease. which the the a the window.. the v
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 9.69150161743164
# ------------captions text = -------------------
# Question: How is the man positioned relative to his surfboard?
# Answer: The man is standing beside his surfboard in the water, holding it or pulling it towards the water.
# ------------Teacher forced predictions text = -------------------
# ,,, a The The is dog dog the the the other?? the the The man is standing on his surfboard, which water. holding ready surf and it it.... is
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 7.071929454803467
# ------------captions text = -------------------
# Question: Are there any other dogs in the image?
# Answer: Yes, there is another dog looking on while the first dog sits on the toy motorcycle.
# ------------Teacher forced predictions text = -------------------
# ,,, a The The the any in in in image of the, Yes, there are other dog in the the the dog dog is the the bench.. the dog
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 10.514163970947266
# ------------captions text = -------------------
# Question: Are there any spectators watching the tennis match?
# Answer: Yes, there are spectators watching the tennis match as the woman serves the ball.
# ------------Teacher forced predictions text = -------------------
# ,,_ the The
#  the any in the the game? the, Yes, there are spectators watching the tennis match in the players players the ball. the are
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 9.288250923156738
# ------------captions text = -------------------
# Question: Is there a dining room visible in the image?
# Answer: Yes, a dining room is visible next to the living room in the image.
# ------------Teacher forced predictions text = -------------------
# ,,_ a The The woman a in in the the image??, Yes, there is room is be in the the table table in the image. The is
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 5.982619285583496
# ------------captions text = -------------------
# Question: What is the color of the wooden bench in the image?
#
# Answer: The color of the wooden bench in the image is brown.
# ------------Teacher forced predictions text = -------------------
# ,,. a The The is the of the dog in in the image?? theThebr> The The color bench the wooden bench in the image is brown. white bench
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 6.142266750335693
# ------------captions text = -------------------
# Question: What is the unique aspect about the way the baseball player in the image is performing the action?
# Answer: The unique aspect of the baseball player's action is his winding up style for the pitch. It seems that his pitching style has a distinctive approach or technique.
# ------------Teacher forced predictions text = -------------------
# ,,, a A The is the of of the image of the is is is image is is the the? the the The baseball aspect about the baseball player in the is the he to the the the,, which is a he is is is be a of, which, w
# Epoch 1/200, Loss: 10.183149337768555
# ------------captions text = -------------------
# Question: Where are the people and their vehicles located in the image?
# Answer: The people and their vehicles are located near a mountainside, standing on top of a dirt hillside, and overlooking a scenic mountain range.
# ------------Teacher forced predictions text = -------------------
# ,,, a The The the the people in horses on parked the image?? the The people and their vehicles are located in a street,, a a a of a... a a a a valley... a are
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 10.40847396850586
# ------------captions text = -------------------
# Question: What is the setting of the image in terms of location and infrastructure?
# Answer: The image shows people in the middle of a road, and the location includes infrastructure like a traffic signal and railroad crossing lights. This indicates that the parade is likely taking place in an urban or suburban area with a well-developed transportation system.
# ------------Teacher forced predictions text = -------------------
# ,,, man A The is the of the scene in?? of and??? The The image is set man a of of a city, a a is is a buildings such,,, a.. The The is that that scene is taking in in in a city area, city, where infra
# Epoch 1/200, Loss: 9.460189819335938
# ------------captions text = -------------------
# Question: Is the apple on top of the bananas or beside them?
# Answer: The green apple is placed on top of the bananas.
# ------------Teacher forced predictions text = -------------------
# ,,_ a A The dog is in plate the plate or the the them? the The apple is is beside beside top of the bunch of the is
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 8.04835319519043
# ------------captions text = -------------------
# Question: How many people are in the group near the toilet?
#
# Answer: The image does not provide an exact number of people in the group. However, it is clear that there is a group of children or young men standing near the toilet.
# ------------Teacher forced predictions text = -------------------
# ,,, a A The is are the in image of the white in? twoThere Answer size There There are is not provide the exact exact of people, the group, the, it is that that there are a group of people people the,
# Epoch 1/200, Loss: 9.029693603515625
# ------------captions text = -------------------
# Question: What gaming console is the child using?
# Answer: The child is using a Nintendo Wii gaming console.
# ------------Teacher forced predictions text = -------------------
# ,,, a The The is is is the in using the a The child is using a Nintendo console console console. play is
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 8.431485176086426
# ------------captions text = -------------------
# Question: What type of table is the man sitting at?
# Answer: The man is sitting at a wooden table.
# ------------Teacher forced predictions text = -------------------
# ,,, a A The is of is the the is using a? a The man is sitting at a wooden table table which is
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 9.144269943237305
# ------------captions text = -------------------
# Question: What is the child doing in the image?
# Answer: The child in the image is brushing his teeth using a blue toothbrush.
# ------------Teacher forced predictions text = -------------------
# ,,, a The The is the of holding the image?? the The child is the image is standing a teeth. a tooth tooth tooth. a is
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 8.159852027893066
# ------------captions text = -------------------
# Question: What type of pizza is visible in the image?
#
# Answer: There's a pepperoni pizza visible in the image.
# ------------Teacher forced predictions text = -------------------
# ,,, a There The is of is is on the image?? A
# br> The The image a large pizza pizza pizza in the image. a is
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 7.710488319396973
# ------------captions text = -------------------
# Question: What color is the dog in the image?
# Answer: The dog in the image is black.
# ------------Teacher forced predictions text = -------------------
# ,,, a The The is is catboard the image?? The The dog in the image is black. white is
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 5.485254287719727
# ------------captions text = -------------------
# Question: What type of vehicle are the people riding on?
#
# Answer: The people are riding on a motorcycle.
# ------------Teacher forced predictions text = -------------------
# ,,, the The The is of is the people in in? the aThe In> The The people are riding on a motorcycle. which are
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 7.993662357330322
# ------------captions text = -------------------
# Question: Is the bread toasted?
# Answer: The image does not provide enough information to confidently determine if the bread is toasted or not.
# ------------Teacher forced predictions text = -------------------
# ,,, a A The man in toasted the, Yes, is not provide provide information to determine determine the if bread isastedasted. However. However,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 9.9281644821167
# ------------captions text = -------------------
# Question: What stage of the baseball game is depicted in the image?
# Answer: The image captures a crucial moment during a baseball game when a pitch is being thrown towards the batter. The batter is in the act of swinging at the incoming baseball, with the intention of hitting it and potentially scoring runs for their team. Simultaneously, the catcher is in a prepared stance, ready to catch the ball if the batter fails to make contact.
# ------------Teacher forced predictions text = -------------------
# ,,, a The The is the the game is is the the image?? The The image shows a the of of the baseball game, a batter is thrown thrown. the batter. the is is is to position of to to the pitch,, which the ba
# Epoch 1/200, Loss: 11.223339080810547
# ------------captions text = -------------------
# Question: What kind of location is the skateboard activity taking place?
# Answer: The skateboarding activity is taking place in a skate park, which is a designated area specifically designed for skateboarding, often featuring ramps, bowls, and other obstacles for skaters to practice their skills and perform tricks.
# ------------Teacher forced predictions text = -------------------
# ,,_ a The The is of is the the in in located taking place? The The skateboard activity is taking place in a parking.. which a a designed for for for for skate and and tricks, with ramps rails, and and
# Epoch 1/200, Loss: 6.573451042175293
# ------------captions text = -------------------
# Question: How many pictures are there in the montage showing the dessert and different stages of serving and eating?
# Answer: There are three pictures in the montage showing the different stages of the dessert being served and eaten.
# ------------Teacher forced predictions text = -------------------
# ,,, a The The the are are in in image??? the's??? the???? There There are two pictures in the montage that the dessert and of serving serving and serving and eaten. The is
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 8.964747428894043
# ------------captions text = -------------------
# Question: What is the cat's position in relation to the clothes and the bag?
# Answer: The cat is lying on top of the clothes and partially inside the gray bag, with its body occupying both spaces.
# ------------Teacher forced predictions text = -------------------
# _,, a A The is on of doing in the image the other and???? The The cat is lying on the clothes the clothes and the the the bag.. It is bag on to space and the cat
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1/200, Loss: 8.831109046936035
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 18
#      14 #loss, predictions = model(embeddings, captions, QTokenLength, ATokens)
#      15
#      16 # Backward pass and optimization
#      17 optimizer.zero_grad()
# ---> 18 loss.backward()
#      19 optimizer.step()
#      20 if ix % 10 == 0:
#
# File /opt/conda/lib/python3.10/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File /opt/conda/lib/python3.10/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
torch.save(
    peft_model.state_dict(),
    "stage_2_model.pth"
)
